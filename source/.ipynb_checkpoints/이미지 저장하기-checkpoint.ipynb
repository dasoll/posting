# %%
import zipfile
import os
import shutil

# %%
def createDirectory(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print("Error: Failed to create the directory.")

# %%
path = '/Users/dasolseo/Downloads/picture'

# %%
for dirpath, dirname, filenames in os.walk(path):
    for file in filenames:
        name, extension = os.path.splitext(file)
        
        print(name, extension)
        if extension == '.zip':
            createDirectory(os.path.join(dirpath, name))
            fantasy_zip = zipfile.ZipFile(os.path.join(dirpath, file))
            fantasy_zip.extractall(os.path.join(dirpath, name))
 
            fantasy_zip.close()
            os.remove(os.path.join(dirpath, file))
# Out:
# takeout-20220924T105727Z-022 .zip
# takeout-20220924T105727Z-023 .zip
# takeout-20220924T105727Z-009 .zip
# takeout-20220924T105727Z-021 .zip
# takeout-20220924T105727Z-020 .zip
# takeout-20220924T105727Z-008 .zip
# takeout-20220924T105727Z-024 .zip
# takeout-20220924T105727Z-018 .zip
# .DS_Store
# takeout-20220924T105727Z-019 .zip
# takeout-20220924T105727Z-025 .zip
# takeout-20220924T105727Z-027 .zip
# RPReplay_Final1624154844-026 .mp4
# RPReplay_Final1632837261-029 .mp4
# takeout-20220924T105727Z-003 .zip
# takeout-20220924T105727Z-017 .zip
# takeout-20220924T105727Z-016 .zip
# takeout-20220924T105727Z-002 .zip
# takeout-20220924T105727Z-014 .zip
# takeout-20220924T105727Z-001 .zip
# takeout-20220924T105727Z-015 .zip
# takeout-20220924T105727Z-011 .zip
# takeout-20220924T105727Z-005 .zip
# takeout-20220924T105727Z-004 .zip
# takeout-20220924T105727Z-010 .zip
# takeout-20220924T105727Z-006 .zip
# takeout-20220924T105727Z-012 .zip
# RPReplay_Final1632866489-028 .mp4
# takeout-20220924T105727Z-013 .zip
# takeout-20220924T105727Z-007 .zip
# .DS_Store
# .DS_Store
# .DS_Store
# IMG_0859.HEIC .json
# IMG_0875.HEIC .json
# IMG_0874.JPG .json
# IMG_0846.HEIC .json
# IMG_1235 .JPG
# IMG_1220 .HEIC
# IMG_0888.HEIC .json
# IMG_0877.HEIC .json
# IMG_1202 .JPG
# IMG_0849.HEIC .json
# IMG_0853.PNG .json
# IMG_1206 .PNG
# SODA_1577881286.mp4 .json
# IMG_1205 .PNG
# IMG_1219 .HEIC
# IMG_0899 .JPG
# IMG_1204 .PNG
# IMG_1210 .PNG
# IMG_0876.MOV .json
# IMG_0834.HEIC .json
# IMG_1260 .JPG
# IMG_0848.PNG .json
# IMG_0845.HEIC .json
# IMG_1842.JPG .json
# IMG_1852.HEIC .json
# IMG_1867.HEIC .json
# IMG_1859.HEIC .json
# IMG_1861.JPG .json
# IMG_1840.HEIC .json
# IMG_1851.GIF .json
# B612.mp4(2) .json
# IMG_1853.HEIC .json
# IMG_1866.HEIC .json
# IMG_2711.JPG .json
# IMG_1862.JPG .json
# IMG_2714.JPG .json
# IMG_1856.HEIC .json
# IMG_1841.JPG .json
# IMG_2688.JPG .json
# IMG_1848.HEIC .json
# IMG_2713.JPG .json
# IMG_1839.HEIC .json
# IMG_6129 .PNG
# IMG_6039 .HEIC
# IMG_0624 .MP4
# IMG_6101(1) .HEIC
# IMG_7385 .HEIC
# IMG_5376.PNG .json
# IMG_7393 .HEIC
# IMG_6078 .HEIC
# IMG_5971 .PNG
# IMG_7357 .JPG
# IMG_5959 .PNG
# IMG_7405 .HEIC
# 3B570342-7051-4FE7-904C-8BBF17C8BC23 .jpg
# IMG_7196 .JPG
# IMG_5933 .MOV
# IMG_6553 .MOV
# IMG_6404 .HEIC
# IMG_6056(1) .HEIC
# IMG_5958 .PNG
# IMG_7356 .JPG
# IMG_6015 .HEIC
# IMG_7274 .MOV
# IMG_6042 .HEIC
# IMG_6107 .HEIC
# IMG_6128 .PNG
# IMG_5409 .PNG
# IMG_5926 .HEIC
# IMG_6170 .HEIC
# IMG_6035 .HEIC
# 5C8D27D0-AC52-49C6-84C4-169B5FF44B96 .jpg
# IMG_7208 .JPG
# IMG_7366 .HEIC
# IMG_6168 .MOV
# IMG_7389 .HEIC
# IMG_7220 .JPG
# IMG_6062 .HEIC
# IMG_5988 .HEIC
# IMG_6008 .MOV
# IMG_7370 .HEIC
# IMG_5966 .PNG
# IMG_5972 .PNG
# IMG_6074 .HEIC
# IMG_6034 .MOV
# IMG_7354 .JPG
# IMG_6118(1) .HEIC
# IMG_5930 .HEIC
# IMG_6070(1) .HEIC
# IMG_6166 .HEIC
# A9D04B23-BF31-4A62-BA8C-D087077CA5A8 .jpg
# IMG_5931 .MOV
# IMG_6084(1) .HEIC
# IMG_7355 .JPG
# IMG_5973 .PNG
# IMG_6326 .HEIC
# IMG_5967 .PNG
# 44A2B1C8-E018-4B1A-854F-6A7C1CD34DE2 .jpg
# 23FD893B-A34F-419C-AA16-B18C6FFDCC7A .jpg
# IMG_6019 .HEIC
# IMG_5676 .MOV
# IMG_6018 .HEIC
# IMG_5321 .HEIC
# IMG_6179 .MOV
# IMG_5289 .MOV
# IMG_7351 .JPG
# IMG_5963 .PNG
# IMG_6327 .HEIC
# IMG_5977 .PNG
# IMG_0601 .JPG
# IMG_6167 .HEIC
# joined_video_255ca4c8510a433cae73287091dbf3f2 .mp4
# IMG_6022 .HEIC
# IMG_7146.HEIC .json
# IMG_5675(1) .HEIC
# IMG_7371 .HEIC
# IMG_5976 .PNG
# IMG_5962 .PNG
# IMG_5989 .HEIC
# IMG_5288 .MOV
# IMG_7367 .HEIC
# IMG_7388 .HEIC
# IMG_6063 .HEIC
# IMG_0623 .MP4
# IMG_0621 .HEIC
# IMG_6171 .HEIC
# IMG_7032 .JPG
# IMG_7275 .HEIC
# IMG_5927 .HEIC
# IMG_6100(1) .HEIC
# IMG_0561 .PNG
# IMG_6043 .HEIC
# IMG_7243 .HEIC
# IMG_7352 .JPG
# IMG_5948 .PNG
# 485D22FA-DEAE-4D1B-AE49-B7E05F2AC868 .jpg
# IMG_8075 .JPG
# IMG_5974 .PNG
# IMG_5960 .PNG
# IMG_5936 .MOV
# IMG_6055 .HEIC
# IMG_7200.JPG .json
# IMG_7066.JPG .json
# IMG_5961 .PNG
# IMG_5975 .PNG
# IMG_7353 .JPG
# IMG_7404 .HEIC
# IMG_6096 .HEIC
# IMG_6455(1) .PNG
# IMG_0740 .MP4
# IMG_7392 .HEIC
# IMG_5993 .HEIC
# IMG_6080 .HEIC
# IMG_7384 .HEIC
# IMG_6139 .PNG
# IMG_6038 .HEIC
# IMG_7187.JPG .json
# IMG_7337 .HEIC
# IMG_7297 .PNG
# IMG_6189 .PNG
# IMG_7283 .PNG
# IMG_5998 .HEIC
# IMG_5669 .PNG
# IMG_5866 .PNG
# IMG_7268 .JPG
# IMG_5872 .PNG
# IMG_6097 .MOV
# IMG_7308 .JPG
# IMG_7376 .HEIC
# IMG_7399 .HEIC
# IMG_6054 .MOV
# IMG_7320 .JPG
# 26AA031C-2966-49B7-B6B4-C24A382436D8.jpg .json
# BC94A1D2-B1CB-451E-B577-8B8656F0B609 .jpg
# IMG_5986 .MOV
# IMG_5382.PNG .json
# IMG_5383.PNG .json
# IMG_5449 .HEIC
# IMG_7309 .JPG
# IMG_6320 .HEIC
# IMG_6009 .HEIC
# IMG_6121 .MOV
# IMG_5677(1) .HEIC
# IMG_5456 .JPG
# IMG_6336 .HEIC
# IMG_5867 .PNG
# IMG_5898 .PNG
# IMG_5668 .PNG
# IMG_6087(1) .HEIC
# IMG_6188 .PNG
# IMG_7296 .PNG
# IMG_6048 .HEIC
# E06DB008-69E2-4726-8A64-ACA1C0188216 .jpg
# IMG_6149 .PNG
# IMG_7280 .PNG
# IMG_7294 .PNG
# IMG_5483 .PNG
# IMG_7383 .HEIC
# IMG_6068 .HEIC
# IMG_6341 .HEIC
# IMG_5865 .PNG
# IMG_6161 .JPG
# IMG_0737.JPG .json
# IMG_5859 .PNG
# IMG_5454 .JPG
# IMG_6091 .HEIC
# IMG_6954 .JPG
# IMG_7395 .HEIC
# IMG_7403 .HEIC
# IMG_5939 .PNG
# IMG_6102(1) .HEIC
# E5FC3804-5B5E-459D-A70C-74AEFCF3F389 .png
# IMG_6029 .PNG
# IMG_5984 .MOV
# IMG_5985 .MOV
# IMG_6028 .PNG
# IMG_6005 .HEIC
# IMG_7244 .HEIC
# IMG_5279 .HEIC
# IMG_7406 .MOV
# IMG_5455 .JPG
# IMG_5858 .PNG
# IMG_5864 .PNG
# IMG_5280 .HEIC
# IMG_5870 .PNG
# IMG_5482 .PNG
# IMG_7295 .PNG
# IMG_6044 .HEIC
# IMG_7281 .PNG
# IMG_0743 .HEIC
# IMG_5469 .PNG
# IMG_6453(1) .PNG
# IMG_0742 .HEIC
# IMG_6415 .HEIC
# IMG_6045 .HEIC
# IMG_6330 .MOV
# 9A2C2AB6-DB93-4356-9C23-7406071CD3F9 .jpg
# IMG_5848 .PNG
# 8F3CFFFC-5862-4E00-8AE1-A89F6D88E8D2 .jpg
# IMG_5860 .PNG
# F682691B-069D-4F5A-AC94-E518B94C8D57 .png
# IMG_6085 .MOV
# IMG_6004 .HEIC
# IMG_5928 .PNG
# IMG_7190.JPG .json
# IMG_6053 .HEIC
# IMG_5995 .MOV
# IMG_6403 .HEIC
# RPReplay_Final1620121963 .mp4
# IMG_5994 .MOV
# 503B1E41-B4DC-46F8-9015-82EABDA3457D .jpg
# 7FBB9D8C-FCBB-48B8-BF87-0F87D33C576E .jpg
# IMG_7402 .HEIC
# IMG_7327 .JPG
# IMG_7119 .PNG
# IMG_6090 .HEIC
# IMG_6944 .JPG
# IMG_7394 .HEIC
# IMG_5861 .PNG
# IMG_6340 .HEIC
# IMG_5875 .PNG
# IMG_7247 .JPG
# -6792934453173513164 .mp4
# IMG_5849 .PNG
# IMG_7284 .JPG
# IMG_7382 .HEIC
# IMG_6069 .HEIC
# IMG_0739 .HEIC
# IMG_6325 .MOV
# -6792934453173513164.mp4 .json
# IMG_5334 .PNG
# IMG_6049 .HEIC
# IMG_7279 .PNG
# IMG_5678 .PNG
# IMG_6072(1) .HEIC
# IMG_7251 .JPG
# IMG_6337 .HEIC
# IMG_5863 .PNG
# IMG_6086 .MOV
# IMG_6946 .JPG
# F8CCE23B-208C-4DC8-8E6B-AEACC0C38F3D.jpg .json
# IMG_7443 .JPG
# IMG_6079 .MOV
# IMG_7319 .JPG
# IMG_6321 .HEIC
# IMG_5982 .MOV
# IMG_5937 .HEIC
# IMG_7318 .JPG
# IMG_7377 .HEIC
# IMG_7324 .JPG
# IMG_7398 .HEIC
# IMG_6073 .HEIC
# IMG_7361 .HEIC
# IMG_5862 .PNG
# IMG_6120 .HEIC
# IMG_7250 .JPG
# 44633A62-3294-4EDA-8D3A-5EA46AB8C3EF .jpg
# IMG_5453 .JPG
# IMG_7418 .HEIC
# IMG_5889 .PNG
# IMG_5661(1) .PNG
# IMG_7336 .HEIC
# IMG_7273 .HEIC
# IMG_5484 .PNG
# IMG_7293 .PNG
# IMG_7278 .PNG
# IMG_5335 .PNG
# IMG_0595.PNG .json
# EA171DAF-A98A-40B7-8024-96E5A169A909 .jpg
# IMG_5310 .PNG
# A337E694-1FD1-46C8-B231-4CA6E961F16F .jpg
# IMG_6058(1) .HEIC
# IMG_6180 .PNG
# IMG_5322(1) .HEIC
# IMG_6158 .HEIC
# IMG_7152.JPG .json
# IMG_5324 .HEIC
# IMG_5890 .PNG
# IMG_7153.JPG .json
# 4CD29430-35D3-4464-A1CD-C542F2C1B24D .mp4
# IMG_7249 .JPG
# IMG_5853 .PNG
# IMG_5462 .JPG
# IMG_7188.JPG .json
# IMG_6962 .JPG
# IMG_6322 .HEIC
# IMG_6083(1) .HEIC
# IMG_7301 .JPG
# IMG_6119 .HEIC
# IMG_7329 .PNG
# _talkv_wpOXdyusjZ_nkVd8e9eM5xw8Fze6CSad1_talkv_ .mp4
# IMG_6032(1) .PNG
# IMG_8039 .HEIC
# IMG_6162 .HEIC
# IMG_7314 .PNG
# IMG_5934 .HEIC
# IMG_7300 .PNG
# IMG_7328 .PNG
# IMG_7065.JPG .json
# IMG_6067(1) .HEIC
# IMG_7374 .HEIC
# IMG_5463 .JPG
# IMG_6436 .HEIC
# IMG_5852 .PNG
# IMG_7248 .JPG
# IMG_7362 .HEIC
# IMG_5661 .PNG
# IMG_0624 .HEIC
# IMG_5885 .PNG
# IMG_6181 .PNG
# IMG_7335 .HEIC
# IMG_6142 .PNG
# IMG_6156 .PNG
# IMG_0741 .HEIC
# 31928703-06AE-4731-A285-8DB62722B185 .jpg
# IMG_5307 .PNG
# IMG_6183 .PNG
# IMG_6046 .HEIC
# IMG_5893 .PNG
# IMG_6338 .HEIC
# IMG_5850 .PNG
# IMG_6154 .JPG
# IMG_6011 .HEIC
# IMG_5461 .JPG
# IMG_5878 .PNG
# IMG_6089 .MOV
# IMG_5447 .HEIC
# IMG_0739 .MP4
# IMG_6051(1) .HEIC
# IMG_6007 .HEIC
# IMG_6456(1) .PNG
# F1F86A04-3276-4107-BF96-F36D7F71C804 .jpg
# IMG_5999 .MOV
# IMG_5298 .PNG
# IMG_6050 .HEIC
# IMG_5938 .HEIC
# IMG_7401 .HEIC
# IMG_7303 .JPG
# IMG_7397 .HEIC
# IMG_6093 .HEIC
# IMG_6996.JPG .json
# IMG_6117 .MOV
# _talkv_wpdyIV50qa_DFziisvsKLSRM3muvVcwHk_talkv .json
# IMG_5460 .JPG
# IMG_6103 .MOV
# IMG_6343 .HEIC
# IMG_5996 .HEIC
# IMG_6155 .JPG
# IMG_5851 .PNG
# IMG_5662 .PNG
# IMG_7381 .HEIC
# IMG_5892 .PNG
# IMG_6106(1) .HEIC
# IMG_6182 .PNG
# IMG_7331(1) .HEIC
# IMG_7277 .PNG
# IMG_6178 .HEIC
# IMG_5470 .PNG
# IMG_6454(1) .PNG
# IMG_7338 .HEIC
# IMG_6151 .PNG
# IMG_3551.HEIC .json
# IMG_7298 .PNG
# IMG_6186 .PNG
# IMG_5493 .HEIC
# IMG_6192 .PNG
# IMG_5672 .PNG
# IMG_7380 .HEIC
# IMG_0722 .PNG
# IMG_5882 .PNG
# IMG_5302 .JPG
# IMG_6342 .HEIC
# IMG_5458 .JPG
# IMG_5855 .PNG
# IMG_5997 .HEIC
# IMG_7396 .HEIC
# IMG_6958 .JPG
# IMG_6092 .HEIC
# IMG_7400 .HEIC
# IMG_5935 .JPG
# IMG_6031 .PNG
# IMG_6030 .PNG
# IMG_6066 .MOV
# IMG_7306 .JPG
# IMG_6099 .MOV
# IMG_6959 .JPG
# IMG_5854 .PNG
# IMG_5459 .JPG
# IMG_6010 .HEIC
# AEB81B71-C93A-4279-A68C-F7DFEF058D6E .jpg
# IMG_7272 .JPG
# IMG_6339 .HEIC
# IMG_5897 .PNG
# IMG_5667 .PNG
# IMG_5673 .PNG
# IMG_6187 .PNG
# IMG_7299 .PNG
# IMG_7064 .JPG
# IMG_6047 .HEIC
# IMG_0740 .HEIC
# IMG_7073.JPG .json
# IMG_6150 .PNG
# IMG_7072.JPG .json
# IMG_5923 .HEIC
# IMG_6319 .HEIC
# IMG_6191 .PNG
# IMG_7334 .HEIC
# IMG_6185 .PNG
# IMG_5665 .PNG
# IMG_5671 .PNG
# IMG_5881 .PNG
# IMG_6110 .MOV
# IMG_5301 .JPG
# IMG_7363 .HEIC
# IMG_5856 .PNG
# IMG_6059(1) .HEIC
# IMG_6071 .HEIC
# IMG_7194.JPG .json
# IMG_7310 .JPG
# IMG_7375 .HEIC
# IMG_7304 .PNG
# IMG_6163 .HEIC
# IMG_7305 .PNG
# IMG_6323 .HEIC
# IMG_7311 .JPG
# IMG_6153 .JPG
# IMG_5857 .PNG
# IMG_5300 .JPG
# 5A7350FB-DC28-43C7-B0E7-0A3CE96BA07C .jpg
# IMG_6159 .HEIC
# IMG_5325 .HEIC
# IMG_5670 .PNG
# IMG_5664 .PNG
# IMG_6184 .PNG
# IMG_6190 .PNG
# IMG_5466 .PNG
# IMG_5401 .PNG
# IMG_5363.JPG .json
# IMG_6105 .HEIC
# IMG_6052(1) .HEIC
# IMG_6134 .JPG
# IMG_6176 .MOV
# IMG_7202 .JPG
# IMG_6017 .HEIC
# IMG_6328 .HEIC
# IMG_5944 .PNG
# IMG_5379.PNG .json
# IMG_7407 .HEIC
# IMG_5945 .PNG
# IMG_7391 .HEIC
# IMG_6095 .HEIC
# IMG_6177 .MOV
# IMG_5990 .HEIC
# IMG_6345 .HEIC
# IMG_7387 .HEIC
# IMG_7368 .HEIC
# IMG_7145.MOV .json
# IMG_6109 .HEIC
# IMG_6123 .PNG
# IMG_5662(1) .PNG
# IMG_5322 .HEIC
# 8CF25F45-DDA4-4192-B1EC-EE38E136E039 .jpg
# IMG_6453 .PNG
# 24EC40D4-5849-4875-9BA7-577366E4230B .jpg
# IMG_6175 .MOV
# IMG_5947 .PNG
# IMG_6324 .HEIC
# 0B5C5328-D398-456C-BE36-11BC653DC268 .mp4
# IMG_7193.JPG .json
# IMG_7192.JPG .json
# IMG_6021 .HEIC
# IMG_6164 .HEIC
# IMG_5932 .HEIC
# IMG_6014 .MOV
# IMG_6076 .HEIC
# IMG_7360 .JPG
# IMG_7372 .HEIC
# IMG_5946 .PNG
# IMG_5284 .MOV
# IMG_6060 .HEIC
# IMG_6174 .MOV
# IMG_7364 .HEIC
# IMG_6064(1) .HEIC
# IMG_6349 .HEIC
# IMG_6452 .PNG
# IMG_7333 .HEIC
# IMG_5924 .HEIC
# C3162FE9-7DF3-4A9D-A939-25DFB1449813 .jpg
# IMG_5925 .HEIC
# IMG_6081(1) .HEIC
# IMG_6126 .PNG
# IMG_6132 .PNG
# IMG_7332 .HEIC
# IMG_0623 .HEIC
# IMG_6456 .PNG
# IMG_6061 .HEIC
# IMG_7365 .HEIC
# IMG_7377(1) .HEIC
# IMG_7246 .MOV
# IMG_0635 .PNG
# IMG_6077 .HEIC
# IMG_7358 .JPG
# IMG_7326 .MOV
# IMG_7373 .HEIC
# IMG_5956 .PNG
# vllo(2) .mp4
# IMG_0609 .JPG
# IMG_6020 .HEIC
# IMG_6165 .HEIC
# IMG_5957 .PNG
# IMG_5943 .PNG
# IMG_7359 .JPG
# IMG_7058.HEIC .json
# IMG_0634 .PNG
# B77DC91D-50EF-4A42-93CB-11FF8447B5D7.jpg .json
# IMG_6133 .JPG
# IMG_5450 .MOV
# CA427B10-DE02-40AF-9B4E-EB367AFAE89D.mp4 .json
# IMG_5323 .HEIC
# IMG_6108 .HEIC
# IMG_6127 .PNG
# IMG_6075(1) .HEIC
# IMG_6065(1) .HEIC
# IMG_7060.HEIC .json
# IMG_6131 .PNG
# IMG_6125 .PNG
# IMG_7184.JPG .json
# IMG_7185.JPG .json
# IMG_7386 .HEIC
# IMG_6455 .PNG
# IMG_6082 .HEIC
# IMG_7369 .HEIC
# IMG_6173 .MOV
# IMG_5991 .HEIC
# IMG_6344 .HEIC
# IMG_6088(1) .HEIC
# IMG_7390 .HEIC
# IMG_6098(1) .HEIC
# IMG_0636 .PNG
# IMG_5969 .PNG
# IMG_6013 .MOV
# IMG_5987 .HEIC
# IMG_5955 .PNG
# _talkv_wpdyIV50qa_DFziisvsKLSRM3muvVcwHk_talkv_ .mp4
# IMG_5941 .PNG
# IMG_6169 .HEIC
# IMG_5315 .HEIC
# IMG_6057 .HEIC
# IMG_7330 .MOV
# IMG_5940 .PNG
# IMG_5954 .PNG
# IMG_6012 .MOV
# 08CABE47-CC6A-42AB-98EF-D200E65C4C7B.jpg .json
# IMG_5968 .PNG
# IMG_6006 .MOV
# IMG_6329 .HEIC
# IMG_5282 .MOV
# IMG_6452(1) .PNG
# IMG_6016 .HEIC
# IMG_6172 .MOV
# IMG_6332 .PNG
# IMG_6454 .PNG
# IMG_6104 .HEIC
# IMG_6041 .HEIC
# IMG_6124 .PNG
# IMG_6130 .PNG

# %%
extensions = []
createDirectory(os.path.join(path, 'all'))


for dirpath, dirname, filenames in os.walk(path):
    for file in filenames:
        name, extension = os.path.splitext(file)        
        if extension not in ['.json', '.html']:
            shutil.move(os.path.join(dirpath, file), os.path.join(os.path.join(path, 'all'), file) )
#         extensions.append(extension)

# %%
import numpy as np
print(np.unique(extensions))
# Out:
# ['' '.GIF' '.HEIC' '.JPG' '.MOV' '.MP4' '.PNG' '.WEBP' '.gif' '.heic'
#  '.html' '.jpg' '.json' '.mov' '.mp4' '.png' '.tiff']
